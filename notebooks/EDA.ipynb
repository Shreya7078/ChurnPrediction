# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1=pd.read_csv('D:\ML Practice\Python\CustomerChurnPrediction\data\WA_Fn-UseC_-Telco-Customer-Churn.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Asus\AppData\Local\Temp\ipykernel_5088\710954109.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df1=pd.read_csv('D:\ML Practice\Python\CustomerChurnPrediction\data\WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df1
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df1['gender'].value_counts()
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
df1['gender'].isnull().sum()
# Out:
# np.int64(0)

# %%
df1['gender'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='gender'>

# %%
df1['SeniorCitizen'].isnull().sum()
# Out:
# np.int64(0)

# %%
df1['SeniorCitizen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SeniorCitizen'>

# %%
df1['Dependents'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Dependents'>

# %%
df1['Dependents'].isnull().sum()
# Out:
# np.int64(0)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df1['SeniorCitizen']=df1['SeniorCitizen'].astype(object)

# %%
df1['SeniorCitizen'].dtypes
# Out:
# dtype('O')

# %%
df1['Partner'].value_counts()
# Out:
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
df1['Partner'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df1['Dependents'].value_counts()
# Out:
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64

# %%
df1['Dependents'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df1['tenure'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
(df1['tenure'] == '').value_counts()
# Out:
# tenure
# False    7043
# Name: count, dtype: int64

# %%
df1['tenure'].describe()
# Out:
# count    7043.000000
# mean       32.371149
# std        24.559481
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: tenure, dtype: float64

# %%
df1['tenure'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df1['PhoneService'].value_counts()
# Out:
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64

# %%
df1['MultipleLines'].value_counts()
# Out:
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64

# %%
df1['InternetService'].value_counts()
# Out:
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
df1['OnlineSecurity'].value_counts()
# Out:
# OnlineSecurity
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: count, dtype: int64

# %%
df1['DeviceProtection'].value_counts()
# Out:
# DeviceProtection
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: count, dtype: int64

# %%
df1['TechSupport'].value_counts()
# Out:
# TechSupport
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: count, dtype: int64

# %%
df1['StreamingTV'].value_counts()
# Out:
# StreamingTV
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: count, dtype: int64

# %%
df1['Contract'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Contract'>

# %%
df1['PaperlessBilling'].value_counts()
# Out:
# PaperlessBilling
# Yes    4171
# No     2872
# Name: count, dtype: int64

# %%
df1['PaymentMethod'].value_counts()
# Out:
# PaymentMethod
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
df1['PaymentMethod'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='PaymentMethod'>

# %%
df1['MonthlyCharges'].value_counts()
# Out:
# MonthlyCharges
# 20.05     61
# 19.85     45
# 19.95     44
# 19.90     44
# 20.00     43
#           ..
# 56.85      1
# 101.70     1
# 48.40      1
# 108.35     1
# 72.00      1
# Name: count, Length: 1585, dtype: int64

# %%
df1['MonthlyCharges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %%
sns.boxplot(df1['MonthlyCharges'])
# Out:
# <Axes: ylabel='MonthlyCharges'>

# %%
df1['TotalCharges'].value_counts()
# Out:
# TotalCharges
# 20.2      11
#           11
# 19.75      9
# 19.65      8
# 19.9       8
#           ..
# 1990.5     1
# 7362.9     1
# 346.45     1
# 306.6      1
# 108.15     1
# Name: count, Length: 6531, dtype: int64

# %%
df1['TotalCharges'].describe()
# Out:
# count     7043
# unique    6531
# top       20.2
# freq        11
# Name: TotalCharges, dtype: object

# %%
df1['TotalCharges'] = pd.to_numeric(df1['TotalCharges'],errors='coerce')

# %%
df1['TotalCharges'].isnull().sum()
# Out:
# np.int64(11)

# %%
df1['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df1['Churn'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Churn'>

# %%
df1['Family'] = ((df1['Partner'] == 'Yes') | (df1['Dependents'] == 'Yes')).astype(int)

# %%
df1['Family']
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7038    1
# 7039    1
# 7040    1
# 7041    1
# 7042    0
# Name: Family, Length: 7043, dtype: int64

# %%
pd.crosstab(df1['Churn'],df1['Family'],normalize='index')
# Out:
# Family         0         1
# Churn
# No      0.416892  0.583108
# Yes     0.600856  0.399144

# %%
sns.countplot(x='Family',hue='Churn',data=df1)
# Out:
# <Axes: xlabel='Family', ylabel='count'>

# %%
sns.barplot(x='Churn',y='tenure',data=df1)
# Out:
# <Axes: xlabel='Churn', ylabel='tenure'>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.hist(df1['tenure'], bins=30)
plt.xlabel('Tenure (months)')
plt.ylabel('Customers')
plt.title('Tenure Distribution')
plt.show()

# %%
bins = [0, 12, 24, 36, 48, 60, 72]
labels = ['0-1yr','1-2yr','2-3yr','3-4yr','4-5yr','5-6yr']

df1['TenureGroup'] = pd.cut(df1['tenure'], bins=bins, labels=labels)

# %%
pd.crosstab(df1['TenureGroup'], df1['Churn'], normalize='index')
# Out:
# Churn              No       Yes
# TenureGroup
# 0-1yr        0.523218  0.476782
# 1-2yr        0.712891  0.287109
# 2-3yr        0.783654  0.216346
# 3-4yr        0.809711  0.190289
# 4-5yr        0.855769  0.144231
# 5-6yr        0.933902  0.066098

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.hist(df1['Contract'], bins=30)
plt.xlabel('Contract')
plt.ylabel('Customers')
plt.title('Contract Distribution')
plt.show()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   object
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
sns.barplot(x='Churn',y='MonthlyCharges',data=df1)
# Out:
# <Axes: xlabel='Churn', ylabel='MonthlyCharges'>

# %%
df1['MonthlyCharges']
# Out:
# 0        29.85
# 1        56.95
# 2        53.85
# 3        42.30
# 4        70.70
#          ...
# 7038     84.80
# 7039    103.20
# 7040     29.60
# 7041     74.40
# 7042    105.65
# Name: MonthlyCharges, Length: 7043, dtype: float64

# %%
sns.barplot(x='Churn',y='TotalCharges',data=df1)
# Out:
# <Axes: xlabel='Churn', ylabel='TotalCharges'>

# %%
pd.crosstab(df1['Churn'],df1['Contract'],normalize='index')
# Out:
# Contract  Month-to-month  One year  Two year
# Churn
# No              0.429068  0.252609  0.318322
# Yes             0.885500  0.088818  0.025682

# %% [markdown]
# # Conclusions
#
# | Factor            | Churn behavior |
# | ----------------- | -------------- |
# | Low tenure        | high churn     |
# | No family         | high churn     |
# | High monthly bill | high churn     |
#
#
# Month to month contract -> High Churn
#
# Electronic Check -> High Churn
#
# Fiber Optic InternetService -> High Churn
#
# No TechSupport -> High Churn
#
# Senior Citizen -> High Churn

# %%
pd.crosstab(df1['Churn'],df1['InternetService'],normalize='index')
# Out:
# InternetService       DSL  Fiber optic        No
# Churn
# No               0.379204     0.347700  0.273096
# Yes              0.245586     0.693954  0.060460

# %%
pd.crosstab(df1['Churn'],df1['TechSupport'],normalize='index')
# Out:
# TechSupport        No  No internet service       Yes
# Churn
# No           0.391767             0.273096  0.335137
# Yes          0.773676             0.060460  0.165864

# %%
pd.crosstab(df1['Churn'],df1['OnlineSecurity'],normalize='index')
# Out:
# OnlineSecurity        No  No internet service       Yes
# Churn
# No              0.393699             0.273096  0.333204
# Yes             0.781701             0.060460  0.157838

# %%
pd.crosstab(df1['Churn'],df1['SeniorCitizen'],normalize='index')
# Out:
# SeniorCitizen         0         1
# Churn
# No             0.871279  0.128721
# Yes            0.745318  0.254682

# %%
pd.crosstab(df1['Churn'],df1['gender'],normalize='index')
# Out:
# gender    Female      Male
# Churn
# No      0.492656  0.507344
# Yes     0.502408  0.497592

# %%
pd.crosstab(df1['PaperlessBilling'], df1['Churn'], normalize='index')
# Out:
# Churn                   No       Yes
# PaperlessBilling
# No                0.836699  0.163301
# Yes               0.664349  0.335651

# %%
pd.crosstab(df1['StreamingTV'], df1['Churn'], normalize='index')
# Out:
# Churn                      No       Yes
# StreamingTV
# No                   0.664769  0.335231
# No internet service  0.925950  0.074050
# Yes                  0.699298  0.300702

# %%
pd.crosstab(df1['StreamingMovies'], df1['Churn'], normalize='index')
# Out:
# Churn                      No       Yes
# StreamingMovies
# No                   0.663196  0.336804
# No internet service  0.925950  0.074050
# Yes                  0.700586  0.299414

# %%
df1[['tenure','MonthlyCharges','TotalCharges']].corr()
# Out:
#                  tenure  MonthlyCharges  TotalCharges
# tenure          1.00000        0.247900      0.825880
# MonthlyCharges  0.24790        1.000000      0.651065
# TotalCharges    0.82588        0.651065      1.000000

# %%
df2 = df1
df2
# Out:
#       customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female             0     Yes         No       1
# 1     5575-GNVDE    Male             0      No         No      34
# 2     3668-QPYBK    Male             0      No         No       2
# 3     7795-CFOCW    Male             0      No         No      45
# 4     9237-HQITU  Female             0      No         No       2
# ...          ...     ...           ...     ...        ...     ...
# 7038  6840-RESVB    Male             0     Yes        Yes      24
# 7039  2234-XADUH  Female             0     Yes        Yes      72
# 7040  4801-JZAZL  Female             0     Yes        Yes      11
# 7041  8361-LTMKD    Male             1     Yes         No       4
# 7042  3186-AJIEK    Male             0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df1.drop(columns=[
    'customerID',
    'TotalCharges',
    'Partner',
    'Dependents',
    'StreamingTV',
    'StreamingMovies'
], inplace=True)

# %%
df1
# Out:
#       gender SeniorCitizen  tenure PhoneService     MultipleLines  \
# 0     Female             0       1           No  No phone service
# 1       Male             0      34          Yes                No
# 2       Male             0       2          Yes                No
# 3       Male             0      45           No  No phone service
# 4     Female             0       2          Yes                No
# ...      ...           ...     ...          ...               ...
# 7038    Male             0      24          Yes               Yes
# 7039  Female             0      72          Yes               Yes
# 7040  Female             0      11           No  No phone service
# 7041    Male             1       4          Yes               Yes
# 7042    Male             0      66          Yes                No
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No          No
# ...

# %%
pd.crosstab(df1['MultipleLines'], df1['Churn'], normalize='index')
# Out:
# Churn                   No       Yes
# MultipleLines
# No                0.749558  0.250442
# No phone service  0.750733  0.249267
# Yes               0.713901  0.286099

# %%
pd.crosstab(df1['DeviceProtection'], df1['Churn'], normalize='index')
# Out:
# Churn                      No       Yes
# DeviceProtection
# No                   0.608724  0.391276
# No internet service  0.925950  0.074050
# Yes                  0.774979  0.225021

# %%
df1['SupportServices'] = (
    (df1['TechSupport']=='Yes') |
    (df1['OnlineSecurity']=='Yes') |
    (df1['DeviceProtection']=='Yes')
).astype(int)

# %%
df1.drop(columns=['TechSupport','OnlineSecurity','DeviceProtection'], inplace=True)

# %%
df1.drop(columns='MultipleLines', inplace=True)

# %%
df1
# Out:
#       gender SeniorCitizen  tenure PhoneService InternetService OnlineBackup  \
# 0     Female             0       1           No             DSL          Yes
# 1       Male             0      34          Yes             DSL           No
# 2       Male             0       2          Yes             DSL          Yes
# 3       Male             0      45           No             DSL           No
# 4     Female             0       2          Yes     Fiber optic           No
# ...      ...           ...     ...          ...             ...          ...
# 7038    Male             0      24          Yes             DSL           No
# 7039  Female             0      72          Yes     Fiber optic          Yes
# 7040  Female             0      11           No             DSL           No
# 7041    Male             1       4          Yes     Fiber optic           No
# 7042    Male             0      66          Yes     Fiber optic           No
#
# ...

# %%
pd.crosstab(df1['PhoneService'],df1['Churn'],normalize='index')
# Out:
# Churn               No       Yes
# PhoneService
# No            0.750733  0.249267
# Yes           0.732904  0.267096

# %%
df1['SupportServices'] = (
    (df1['SupportServices'] == 1) |
    (df1['OnlineBackup'] == 'Yes')
).astype(int)

# %%
df1.drop(columns=['OnlineBackup','PhoneService'], inplace=True)

# %%
df1
# Out:
#       gender SeniorCitizen  tenure InternetService        Contract  \
# 0     Female             0       1             DSL  Month-to-month
# 1       Male             0      34             DSL        One year
# 2       Male             0       2             DSL  Month-to-month
# 3       Male             0      45             DSL        One year
# 4     Female             0       2     Fiber optic  Month-to-month
# ...      ...           ...     ...             ...             ...
# 7038    Male             0      24             DSL        One year
# 7039  Female             0      72     Fiber optic        One year
# 7040  Female             0      11             DSL  Month-to-month
# 7041    Male             1       4     Fiber optic  Month-to-month
# 7042    Male             0      66     Fiber optic        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges Churn  \
# 0                 Yes           Electronic check           29.85    No
# ...

# %%
df1.head()
# Out:
#    gender SeniorCitizen  tenure InternetService        Contract  \
# 0  Female             0       1             DSL  Month-to-month
# 1    Male             0      34             DSL        One year
# 2    Male             0       2             DSL  Month-to-month
# 3    Male             0      45             DSL        One year
# 4  Female             0       2     Fiber optic  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges Churn  Family  \
# 0              Yes           Electronic check           29.85    No       1
# 1               No               Mailed check           56.95    No       0
# 2              Yes               Mailed check           53.85   Yes       0
# 3               No  Bank transfer (automatic)           42.30    No       0
# 4              Yes           Electronic check           70.70   Yes       0
#
#   TenureGroup  SupportServices
# 0       0-1yr                1
# 1       2-3yr                1
# ...

# %%
df1.drop(columns=['TenureGroup'], inplace=True)

# %%
df1
# Out:
#       gender SeniorCitizen  tenure InternetService        Contract  \
# 0     Female             0       1             DSL  Month-to-month
# 1       Male             0      34             DSL        One year
# 2       Male             0       2             DSL  Month-to-month
# 3       Male             0      45             DSL        One year
# 4     Female             0       2     Fiber optic  Month-to-month
# ...      ...           ...     ...             ...             ...
# 7038    Male             0      24             DSL        One year
# 7039  Female             0      72     Fiber optic        One year
# 7040  Female             0      11             DSL  Month-to-month
# 7041    Male             1       4     Fiber optic  Month-to-month
# 7042    Male             0      66     Fiber optic        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges Churn  \
# 0                 Yes           Electronic check           29.85    No
# ...

# %%
df1.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# tenure              0
# InternetService     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# Churn               0
# Family              0
# SupportServices     0
# dtype: int64

# %%
df1.to_csv('D:\ML Practice\Python\CustomerChurnPrediction\data/clean_data.csv', index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Asus\AppData\Local\Temp\ipykernel_5088\2550809665.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df1.to_csv('D:\ML Practice\Python\CustomerChurnPrediction\data/clean_data.csv', index=False)
